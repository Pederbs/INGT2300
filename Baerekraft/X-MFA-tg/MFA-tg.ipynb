# %% [markdown]
# ## Material flow analysis — practice
# This non-obligatory notebook covers the material provided in the material flow analysis part of the curriculum.\
# The notebook includes practice exercises followed by validation cells that instantly show if the exercise is being solved correctly.

# %%
import numpy as np
from IPython.display import Image
Image(filename='ex1.jpg')

# %%
def CalculateFlowX3(X1, X2, X4):
    X3 = X1 + X2 - X4
    return X3

X1_test = 150
X2_test = 100
X4_test = 50

X3_test = CalculateFlowX3(X1_test, X2_test, X4_test)
X3_test
Image(filename='ex1a.jpg')

# %%
A = 2000
B = 0.2
C = 0.8
X3 = CalculateFlowX3(A, A*B, C*(A+A*B))
print(X3)
Image(filename='ex1b.jpg')
# Out:
# 480.0

# %%
k1 = A/(A+A*B)
Image(filename='ex1c.jpg')

# %%
k3 = X3/(A+A*B)
Image(filename='ex2.jpg')

# %%
A = 2000
B = 0.7
C = 0.8
A_test = np.array([[1,1,-1,-1],[1,0,0,0],[-B,1,0,0],[-C,-C,1,0]])
y_test = np.array([[0],[A],[0],[0]])
# Calculating x = A^-1*y
x_test = np.linalg.inv(A_test)@y_test
x_test
